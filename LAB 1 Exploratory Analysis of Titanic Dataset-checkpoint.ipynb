# %% [markdown]
# # Titanic analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing test and train datasets

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
train.loc[train["Age"].idxmax()]
# Out:
# PassengerId                                     631
# Survived                                          1
# Pclass                                            1
# Name           Barkworth, Mr. Algernon Henry Wilson
# Sex                                            male
# Age                                            80.0
# SibSp                                             0
# Parch                                             0
# Ticket                                        27042
# Fare                                           30.0
# Cabin                                           A23
# Embarked                                          S
# Name: 630, dtype: object

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# # Importing Data

# %% [markdown]
# 1) Create training and testing dataframes from the downloaded csv files. Find
#
# A) number of rows in training and test sets

# %%
print("Number of rows in train dataset: ",len(train))
print("Number of rows in test dataset: ",len(test))
# Out:
# Number of rows in train dataset:  891
# Number of rows in test dataset:  418

# %% [markdown]
# B) display the structure of the dataset along with the datatypes of the fields

# %%
print("Structure of Datasets train\n\n",str(train))
# Out:
# Structure of Datasets train
#
#       PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
print("Datatype of train dataset:\n\n",train.dtypes)
# Out:
# Datatype of train dataset:
#
#  PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
print("Structure of Datasets test\n\n",str(test))
# Out:
# Structure of Datasets test
#
#       PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
print("Datatype of train dataset: \n\n", test.dtypes)
# Out:
# Datatype of train dataset:
#
#  PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # Data cleaning

# %% [markdown]
# 1. Analyse the data and identify which columns are not relevant for survivor prediction task. Drop those columns from the dataframes.

# %%
dptrain = train.drop(["Embarked", "Ticket","Pclass","Cabin"], axis = 1)
dptrain
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch     Fare
# 0      male  22.0      1      0   7.2500
# 1    female  38.0      1      0  71.2833
# 2    female  26.0      0      0   7.9250
# 3    female  35.0      1      0  53.1000
# 4      male  35.0      0      0   8.0500
# ..      ...   ...    ...    ...      ...
# 886    male  27.0      0      0  13.0000
# 887  female  19.0      0      0  30.0000
# 888  female   NaN      1      2  23.4500
# 889    male  26.0      0      0  30.0000
# 890    male  32.0      0      0   7.7500
#
# [891 rows x 8 columns]

# %%
dptest = test.drop(["Embarked", "Ticket","Pclass","Cabin"], axis = 1)
dptest
# Out:
#      PassengerId                                          Name     Sex   Age  \
# 0            892                              Kelly, Mr. James    male  34.5
# 1            893              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2            894                     Myles, Mr. Thomas Francis    male  62.0
# 3            895                              Wirz, Mr. Albert    male  27.0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..           ...                                           ...     ...   ...
# 413         1305                            Spector, Mr. Woolf    male   NaN
# 414         1306                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415         1307                  Saether, Mr. Simon Sivertsen    male  38.5
# 416         1308                           Ware, Mr. Frederick    male   NaN
# 417         1309                      Peter, Master. Michael J    male   NaN
#
#      SibSp  Parch      Fare
# 0        0      0    7.8292
# 1        1      0    7.0000
# 2        0      0    9.6875
# 3        0      0    8.6625
# 4        1      1   12.2875
# ..     ...    ...       ...
# 413      0      0    8.0500
# 414      0      0  108.9000
# 415      0      0    7.2500
# 416      0      0    8.0500
# 417      1      1   22.3583
#
# [418 rows x 7 columns]

# %% [markdown]
# 2. Check how many columns have missing values in them (NA) and how many have NaN values. Logically impute the dataset.

# %%
print("Columns with missing values and count of NaN values: in test datasets: \n\n",dptrain.isnull().sum())
# Out:
# Columns with missing values and count of NaN values: in test datasets:
#
#  PassengerId      0
# Survived         0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# dtype: int64

# %%
dptrain["Age"] = dptrain["Age"].replace(np.nan, dptest["Age"].mean())
dptrain.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# dtype: int64

# %%
dptrain.duplicated().any()
# Out:
# False

# %%
print("Columns with missing values and count of NaN values: in train datasets: \n\n",dptest.isnull().sum())
# Out:
# Columns with missing values and count of NaN values: in train datasets:
#
#  PassengerId     0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Fare            1
# dtype: int64

# %%
dptest["Fare"] = dptest["Fare"].replace(np.nan, dptest["Fare"].mean())
dptest["Age"] = dptest["Age"].replace(np.nan, dptest["Age"].mean())
dptest.isnull().sum()
# Out:
# PassengerId    0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# dtype: int64

# %%
dptest.duplicated().any()
# Out:
# False

# %% [markdown]
# 3. Identify any categorical valued columns (non-numeric) and convert them to numeric.
# Male = 0
# Female = 1

# %%
dptrain['Sex'].replace(['male','female'],[0,1], inplace = True)
dptrain
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
#      Sex   Age  SibSp  Parch     Fare
# 0      0  22.0      1      0   7.2500
# 1      1  38.0      1      0  71.2833
# 2      1  26.0      0      0   7.9250
# 3      1  35.0      1      0  53.1000
# 4      0  35.0      0      0   8.0500
# ..   ...   ...    ...    ...      ...
# 886    0  27.0      0      0  13.0000
# 887    1  19.0      0      0  30.0000
# 888    1   NaN      1      2  23.4500
# 889    0  26.0      0      0  30.0000
# 890    0  32.0      0      0   7.7500
#
# [891 rows x 8 columns]

# %%
dptest['Sex'].replace(['male','female'],[0,1], inplace = True)
dptest
# Out:
#      PassengerId                                          Name  Sex   Age  \
# 0            892                              Kelly, Mr. James    0  34.5
# 1            893              Wilkes, Mrs. James (Ellen Needs)    1  47.0
# 2            894                     Myles, Mr. Thomas Francis    0  62.0
# 3            895                              Wirz, Mr. Albert    0  27.0
# 4            896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.0
# ..           ...                                           ...  ...   ...
# 413         1305                            Spector, Mr. Woolf    0   NaN
# 414         1306                  Oliva y Ocana, Dona. Fermina    1  39.0
# 415         1307                  Saether, Mr. Simon Sivertsen    0  38.5
# 416         1308                           Ware, Mr. Frederick    0   NaN
# 417         1309                      Peter, Master. Michael J    0   NaN
#
#      SibSp  Parch      Fare
# 0        0      0    7.8292
# 1        1      0    7.0000
# 2        0      0    9.6875
# 3        0      0    8.6625
# 4        1      1   12.2875
# ..     ...    ...       ...
# 413      0      0    8.0500
# 414      0      0  108.9000
# 415      0      0    7.2500
# 416      0      0    8.0500
# 417      1      1   22.3583
#
# [418 rows x 7 columns]

# %% [markdown]
# # Exploratory Analysis (On training set):

# %% [markdown]
# 1. Show how many passengers were male and female and plot using matplotlib. On the same plot depict the people who survived and who died. Make accurate axis and legend. Save the plot in a png file.

# %%
sns.countplot('Sex', hue='Survived', data=train, palette = "rocket")
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
df = train.groupby(["Sex","Survived"])["Survived"].count()
print(df)
df1 = pd.DataFrame({
    'Sex': ['Male', 'Female'],
    'Survived': [df[3],df[1]],
    'Died': [df[2],df[0]]
})

df1.plot(x='Sex', y=["Survived", "Died"], kind="bar", color=['#FF6A6A','#009ACD'])
plt.ylabel("Survived and Died")
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64
# Text(0, 0.5, 'Survived and Died')

# %% [markdown]
# Based on the graph, men have a survival rate of around 20% and women have a survival rate of around 75%. As a result, whether a passenger is male or female has a significant impact on whether or not he or she will survive.

# %% [markdown]
# 2. Show the histogram of the count of passengers who died (according to their age). Age ranges should be <10, 10 to <20, 20 to <30 and so on.

# %%
df1 = train[train['Survived'] == 0]['Age']
df2 = train[train['Survived'] == 1]['Age']
max_age = max(train['Age'])
plt.hist([df1, df2], 
             bins=10, 
             range=(1, max_age), 
             stacked=True,edgecolor = "black", color=['#FFAEBC', '#A0E7E5'])
plt.legend(('Died', 'Survived'), loc='best')
plt.title('Survivors by Age Group')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# How many minor children died and how many of them survived (<16 years). Create a separate plot for the passengers who survived.

# %%
df2 = train[train['Survived'] == 1]['Age']
print("Total Survived Passengers less than 16 years are", train['Age'][(train["Survived"] == 1) & (train["Age"] < 16)].count())

max_age = max(train['Age'])
plt.hist(df2, 
             bins=16, 
             range=(1, 16), 
             stacked=True,edgecolor = "black")
plt.legend(('Alive', 'Survived'), loc='best')
plt.title('Survivors below 16')
plt.ylabel('Count')
plt.xlabel("Below 16")
# Out:
# Total Survived Passengers less than 16 years are 49
# Text(0.5, 0, 'Below 16')

# %% [markdown]
# 3. Show the distribution on the count of passengers who died (according to the fare they paid). Choose fare ranges such that the mean lies in the middle range.
#
#     Give the percentage of passengers who survived as had paid more than $100. Justify if there was any bias in the rescue operation towards the rich (Yes/No/not enough evidence).

# %%
dptrain['FareBand'] = pd.qcut(dptrain['Fare'], 25)
dptrain[['FareBand', 'Survived']].groupby(['FareBand'], as_index=False).mean().sort_values(by='FareBand', ascending=True)
# Out:
#              FareBand  Survived
# 0     (-0.001, 7.053]  0.055556
# 1       (7.053, 7.25]  0.191489
# 2        (7.25, 7.75]  0.315789
# 3       (7.75, 7.775]  0.187500
# 4      (7.775, 7.854]  0.304348
# 5      (7.854, 7.896]  0.113636
# 6       (7.896, 8.05]  0.225806
# 7         (8.05, 8.1]       NaN
# 8          (8.1, 9.5]  0.159091
# 9         (9.5, 10.5]  0.323529
# 10       (10.5, 13.0]  0.461538
# 11     (13.0, 13.083]       NaN
# 12   (13.083, 15.246]  0.289474
# 13    (15.246, 17.88]  0.484848
# 14    (17.88, 21.679]  0.444444
# 15     (21.679, 26.0]  0.459016
# 16     (26.0, 26.308]  0.800000
# 17   (26.308, 28.942]  0.371429
# 18   (28.942, 31.388]  0.461538
# 19   (31.388, 39.688]  0.371429
# 20     (39.688, 53.1]  0.428571
# 21      (53.1, 69.55]  0.611111
# 22    (69.55, 82.171]  0.617647
# 23   (82.171, 133.99]  0.828571
# 24  (133.99, 512.329]  0.722222

# %% [markdown]
# 4. Plot graphs showing correlation between different pairs of attributes. Infer if there is any significant correlation between survivors and any specific feature.

# %%
sns.pairplot(dptest)

# %% [markdown]
# 5. Find the number of passengers who were married.

# %%
train["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object
